# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('supermarket_sales.db')

# %%
query = """
SELECT ProductLine,
       SUM(Quantity) AS TotalQuantity,
       SUM(Total) AS Revenue
FROM supermarket_sales_cleaned
GROUP BY ProductLine
ORDER BY Revenue DESC;
"""

df = pd.read_sql_query(query, conn)
print(df)
# Out:
#               ProductLine  TotalQuantity   Revenue
# 0      Food and beverages            952  56144.87
# 1       Sports and travel            920  55122.89
# 2  Electronic accessories            971  54337.55
# 3     Fashion accessories            902  54305.89
# 4      Home and lifestyle            911  53861.87
# 5       Health and beauty            854  49193.81

# %%
plt.figure(figsize=(10,5))

plt.bar(df["ProductLine"], df["Revenue"])

plt.title("Revenue by Product Line")

plt.xticks(rotation=45)

plt.show()

# %%
conn.close()
